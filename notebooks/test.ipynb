# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display

import os
import sys
import importlib

sys.path.insert(0, "..")

import draughts
import board
import engine

importlib.reload(draughts);
importlib.reload(board);
importlib.reload(engine);

# %%
import draughts

# %%
my_board = draughts.Board()
my_board
# Out:
# . o . o . o . o
# o . o . o . o .
# . o . o . o . o
# . . . . . . . .
# . . . . . . . .
# O . O . O . O .
# . O . O . O . O
# O . O . O . O .

# %%
# my_board.engine.force_push(engine.Move("f6d4"))

# %%
my_board.push("e3d4")
my_board.show()
# Out:
# <PIL.Image.Image image mode=RGB size=378x378 at 0x16A9D5220>

# %%
my_board.engine.valid_moves_from_index(engine.BoardBase.get_index("f4"))
# Out:
# [(f4d6, 0.9980167), (f4h6, 0.99984956), (f4e5, 0.99980664), (f4g5, 0.99979734)]
