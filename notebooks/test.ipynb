# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display

import os
import sys
import importlib

sys.path.insert(0, "..")

import draughts
import board
import engine

importlib.reload(draughts);
importlib.reload(board);
importlib.reload(engine);

# %%
import draughts

# %%
my_board = draughts.Board()
my_board
# Out:
# . o . o . o . o
# o . o . o . o .
# . o . o . o . o
# . . . . . . . .
# . . . . . . . .
# O . O . O . O .
# . O . O . O . O
# O . O . O . O .

# %%
# my_board.engine.force_push(engine.Move("f6d4"))

# %%
my_board.push("c5e3 g5")
# my_board.push("e3d4")
# my_board.push("d6c5")
my_board.show()
# Out:
# <PIL.Image.Image image mode=RGB size=378x378 at 0x117986A30>

# %%
my_board.valid_moves()
# Out:
# (Move( a3b4 ),
#  Move( c3b4 ),
#  Move( c3d4 ),
#  Move( d2e3 ),
#  Move( f2e3 ),
#  Move( f2g3 ),
#  Move( h2g3 ))
