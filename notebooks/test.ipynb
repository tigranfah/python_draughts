# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display

import os
import sys
import importlib

sys.path.insert(0, "..")

import draughts
import board
import engine

importlib.reload(draughts);
importlib.reload(board);
importlib.reload(engine);

# %%
import draughts

# %%
my_board = draughts.Board()

# %%
my_board.net_push("d4f2")
my_board.show()
# Out:
# 0.7284908
# 42 53
# <PIL.Image.Image image mode=RGB size=284x284 at 0x163777A30>
